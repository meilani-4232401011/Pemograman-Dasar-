# %% [markdown]
# <a href="https://colab.research.google.com/github/meilani-4232401011/Pemograman-Dasar-/blob/main/Pertemuan_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Nama: Meilani**
#
# **Nim: 4232401011**
#
# Berikut ini adalah pemerogramannya dan penjelasan di bawah nya

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Digunakan untuk menghubungkan Google Drive ke Google Colab sehingga file di Drive bisa dibaca dan disimpan di Colab.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# - import numpy as np, Digunakan untuk mengolah data numerik dan
# melakukan perhitungan matematika dengan array.
# - import pandas as pd, Digunakan untuk mengelola dan menganalisis data dalam bentuk tabel (DataFrame).
# - import matplotlib.pyplot as plt, Digunakan untuk membuat grafik atau visualisasi data.
# - import seaborn as sns, Digunakan untuk membuat grafik statistik yang lebih rapi dan informatif.

# %%
customers_df =pd.read_csv("/content/drive/MyDrive/Pemerograman Dasar/Data/customers.csv")
customers_df.head()
# Out:
#    customer_id customer_name             gender  age  \
# 0            1       fulan 1             Female   30
# 1            2       fulan 2  Prefer not to say   69
# 2            3       fulan 3  Prefer not to say   59
# 3            4       fulan 4  Prefer not to say   67
# 4            5       fulan 5  Prefer not to say   30
#
#                      home_address  zip_code               city  \
# 0  8606 Victoria TerraceSuite 560      5464      Johnstonhaven
# 1      8327 Kirlin SummitApt. 461      8223    New Zacharyfort
# 2       269 Gemma SummitSuite 109      5661           Aliburgh
# 3       743 Bailey GroveSuite 141      1729  South Justinhaven
# 4         48 Hyatt ManorSuite 375      4032     Griffithsshire
#
#                           state    country
# 0            Northern Territory  Australia
# 1               South Australia  Australia
# 2  Australian Capital Territory  Australia
# 3                    Queensland  Australia
# 4                    Queensland  Australia

# %% [markdown]
# - Digunakan untuk membaca file CSV bernama customers.csv dari Google Drive dan menyimpannya ke dalam DataFrame bernama customers_df.
# - Digunakan untuk menampilkan 5 baris pertama dari DataFrame customers_df agar kita bisa melihat struktur dan isi data.

# %%
orders_df =pd.read_csv("/content/drive/MyDrive/Pemerograman Dasar/Data/orders.csv")
orders_df.head()
# Out:
#    order_id  customer_id  payment order_date delivery_date
# 0         1           64    30811  2021-8-30    2021-09-24
# 1         2          473    50490   2021-2-3    2021-02-13
# 2         3          774    46763  2021-10-8    2021-11-03
# 3         4          433    39782   2021-5-6    2021-05-19
# 4         5          441    14719  2021-3-23    2021-03-24

# %% [markdown]
# - Digunakan untuk membaca file CSV bernama orders.csv dari Google Drive dan menyimpannya ke dalam DataFrame orders_df.
# - Digunakan untuk menampilkan 5 baris pertama dari DataFrame orders_df untuk melihat struktur dan isi data.

# %%
products_df =pd.read_csv("/content/drive/MyDrive/Pemerograman Dasar/Data/products.csv")
products_df.head()
# Out:
#    product_id product_type  product_name size colour  price  quantity  \
# 0           0        Shirt  Oxford Cloth   XS    red    114        66
# 1           1        Shirt  Oxford Cloth    S    red    114        53
# 2           2        Shirt  Oxford Cloth    M    red    114        54
# 3           3        Shirt  Oxford Cloth    L    red    114        69
# 4           4        Shirt  Oxford Cloth   XL    red    114        47
#
#                                     description
# 0  A red coloured, XS sized, Oxford Cloth Shirt
# 1   A red coloured, S sized, Oxford Cloth Shirt
# 2   A red coloured, M sized, Oxford Cloth Shirt
# 3   A red coloured, L sized, Oxford Cloth Shirt
# 4  A red coloured, XL sized, Oxford Cloth Shirt

# %% [markdown]
# - Digunakan untuk membaca file CSV bernama products.csv dari Google Drive dan menyimpannya ke dalam DataFrame products_df.
# - Digunakan untuk menampilkan 5 baris pertama dari DataFrame products_df untuk melihat struktur dan isi data.

# %%
sales_df =pd.read_csv("/content/drive/MyDrive/Pemerograman Dasar/Data/sales.csv")
sales_df.head()
# Out:
#    sales_id  order_id  product_id  price_per_unit  quantity  total_price
# 0         0         1         218             106         2        212.0
# 1         1         1         481             118         1        118.0
# 2         2         1           2              96         3        288.0
# 3         3         1        1002             106         2        212.0
# 4         4         1         691             113         3        339.0

# %% [markdown]
# - Digunakan untuk membaca file CSV bernama sales.csv dari Google Drive dan menyimpannya ke dalam DataFrame sales_df.
# - Digunakan untuk menampilkan 5 baris pertama dari DataFrame sales_df untuk melihat struktur dan isi data.

# %%
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1007 entries, 0 to 1006
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    1007 non-null   int64
#  1   customer_name  1007 non-null   object
#  2   gender         989 non-null    object
#  3   age            1007 non-null   int64
#  4   home_address   1007 non-null   object
#  5   zip_code       1007 non-null   int64
#  6   city           1007 non-null   object
#  7   state          1007 non-null   object
#  8   country        1007 non-null   object
# dtypes: int64(3), object(6)
# memory usage: 70.9+ KB

# %% [markdown]
# Digunakan untuk menampilkan struktur dan tipe data pada DataFrame customers_df.

# %%
customers_df.isna().sum()
# Out:
# customer_id       0
# customer_name     0
# gender           18
# age               0
# home_address      0
# zip_code          0
# city              0
# state             0
# country           0
# dtype: int64

# %% [markdown]
# Digunakan untuk menampilkan jumlah data kosong (NaN) pada setiap kolom di DataFrame customers_df.

# %%
print("Jumlah duplikasi: ", customers_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  6

# %% [markdown]
# Digunakan untuk menampilkan jumlah baris data yang terduplikasi pada DataFrame customers_df.

# %%
customers_df.describe()
# Out:
#        customer_id          age     zip_code
# count  1007.000000  1007.000000  1007.000000
# mean    501.726912    50.929494  5012.538232
# std     288.673238    30.516299  2885.836112
# min       1.000000    20.000000     2.000000
# 25%     252.500000    34.000000  2403.500000
# 50%     502.000000    50.000000  5087.000000
# 75%     751.500000    65.000000  7493.500000
# max    1000.000000   700.000000  9998.000000

# %% [markdown]
# Digunakan untuk menampilkan ringkasan statistik data numerik, seperti rata-rata, nilai minimum, maksimum, dan kuartil.

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       1000 non-null   int64
#  1   customer_id    1000 non-null   int64
#  2   payment        1000 non-null   int64
#  3   order_date     1000 non-null   object
#  4   delivery_date  1000 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 39.2+ KB

# %% [markdown]
# Digunakan untuk menampilkan struktur dan tipe data pada DataFrame orders_df.

# %%
print("Jumlah duplikasi: ",orders_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# Digunakan untuk menampilkan jumlah baris data yang terduplikasi pada DataFrame orders_df.

# %%
orders_df.describe()
# Out:
#           order_id  customer_id       payment
# count  1000.000000  1000.000000   1000.000000
# mean    500.500000   506.640000  33972.936000
# std     288.819436   277.115502  14451.609047
# min       1.000000     1.000000  10043.000000
# 25%     250.750000   275.250000  21329.250000
# 50%     500.500000   515.000000  33697.500000
# 75%     750.250000   737.250000  46249.000000
# max    1000.000000  1000.000000  59910.000000

# %% [markdown]
# Digunakan untuk menampilkan ringkasan statistik data numerik pada DataFrame orders_df.

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1266 entries, 0 to 1265
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_id    1266 non-null   int64
#  1   product_type  1266 non-null   object
#  2   product_name  1266 non-null   object
#  3   size          1266 non-null   object
#  4   colour        1266 non-null   object
#  5   price         1266 non-null   int64
#  6   quantity      1266 non-null   int64
#  7   description   1266 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 79.3+ KB

# %% [markdown]
# Digunakan untuk menampilkan struktur dan tipe data pada DataFrame products_df.

# %%
print("Jumlah duplikasi: ", products_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  6

# %% [markdown]
# Digunakan untuk menampilkan jumlah baris data yang terduplikasi pada DataFrame products_df.

# %%
products_df.describe()
# Out:
#         product_id        price     quantity
# count  1266.000000  1266.000000  1266.000000
# mean    627.926540   105.812006    60.138231
# std     363.971586     9.715611    11.682791
# min       0.000000    90.000000    40.000000
# 25%     313.250000    95.250000    50.000000
# 50%     626.500000   109.000000    60.000000
# 75%     942.750000   114.000000    70.000000
# max    1259.000000   119.000000    80.000000

# %% [markdown]
# Digunakan untuk menampilkan ringkasan statistik data numerik pada DataFrame products_df.

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sales_id        5000 non-null   int64
#  1   order_id        5000 non-null   int64
#  2   product_id      5000 non-null   int64
#  3   price_per_unit  5000 non-null   int64
#  4   quantity        5000 non-null   int64
#  5   total_price     4981 non-null   float64
# dtypes: float64(1), int64(5)
# memory usage: 234.5 KB

# %% [markdown]
# Digunakan untuk menampilkan struktur dan tipe data pada DataFrame sales_df.

# %%
sales_df.isna().sum()
# Out:
# sales_id           0
# order_id           0
# product_id         0
# price_per_unit     0
# quantity           0
# total_price       19
# dtype: int64

# %% [markdown]
# Digunakan untuk menampilkan jumlah data kosong (NaN) pada setiap kolom di DataFrame sales_df.

# %%
print("Jumlah duplikasi: ", sales_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# Digunakan untuk menampilkan jumlah baris data yang terduplikasi pada DataFrame sales_df.

# %%
sales_df.describe()
# Out:
#           sales_id     order_id   product_id  price_per_unit    quantity  \
# count  5000.000000  5000.000000  5000.000000     5000.000000  5000.00000
# mean   2499.500000   503.038200   634.053200      103.501600     1.99240
# std    1443.520003   285.964418   363.255794        9.195004     0.80751
# min       0.000000     1.000000     1.000000       90.000000     1.00000
# 25%    1249.750000   258.000000   323.000000       95.000000     1.00000
# 50%    2499.500000   504.500000   635.000000      102.000000     2.00000
# 75%    3749.250000   749.000000   951.000000      112.000000     3.00000
# max    4999.000000   999.000000  1259.000000      119.000000     3.00000
#
#        total_price
# count  4981.000000
# mean    206.307368
# std      86.352449
# min      90.000000
# 25%     112.000000
# 50%     204.000000
# 75%     285.000000
# max     357.000000

# %% [markdown]
# Digunakan untuk menampilkan ringkasan statistik data numerik pada DataFrame sales_df.

# %%
customers_df.drop_duplicates(inplace=True)

# %% [markdown]
# Digunakan untuk menghapus data duplikat pada DataFrame customers_df dan langsung menyimpan perubahannya tanpa membuat DataFrame baru.

# %%
print("Jumlah duplikasi: ", customers_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# Digunakan untuk menampilkan jumlah data duplikat yang tersisa pada DataFrame customers_df.

# %%
customers_df[customers_df.gender.isna()]
# Out:
#      customer_id customer_name gender  age                     home_address  \
# 38            39      fulan 39    NaN   80  7440 Cameron Estate DrSuite 628
# 167          168     fulan 168    NaN   27         2781 Berge MallSuite 452
# 322          322     fulan 322    NaN   30        593 Becker CircleApt. 333
# 393          393     fulan 393    NaN   34          5158 Levi HillSuite 531
# 442          442     fulan 442    NaN   26           5157 Feil RoadApt. 633
# 722          720     fulan 720    NaN   40         31 Jordan ParadeApt. 400
# 745          743     fulan 743    NaN   57   09 Christopher StreetSuite 967
# 773          771     fulan 771    NaN   74     7367 Wright JunctionApt. 773
# 798          795     fulan 795    NaN   49          487 Summer MewsApt. 874
# 801          798     fulan 798    NaN   56           27 Aiden KnollApt. 875
# 825          822     fulan 822    NaN   59        41 Jenkins KnollSuite 438
# ...

# %% [markdown]
# Digunakan untuk menampilkan baris data pelanggan yang kolom gender-nya kosong (NaN) pada DataFrame customers_df.

# %%
customers_df.gender.value_counts()
# Out:
# gender
# Prefer not to say    725
# Male                 143
# Female               115
# Name: count, dtype: int64

# %% [markdown]
# Digunakan untuk menghitung jumlah masing-masing kategori nilai pada kolom gender di DataFrame customers_df.

# %%
customers_df.isna().sum()
# Out:
# customer_id       0
# customer_name     0
# gender           18
# age               0
# home_address      0
# zip_code          0
# city              0
# state             0
# country           0
# dtype: int64

# %% [markdown]
# Digunakan untuk menampilkan jumlah data kosong (NaN) pada setiap kolom di DataFrame customers_df.

# %%
customers_df[customers_df.age == customers_df.age.max()]
# Out:
#      customer_id customer_name             gender  age  \
# 967          961     fulan 961  Prefer not to say  700
#
#                    home_address  zip_code        city            state  \
# 967  29 Farrell ParadeSuite 818      6528  New Joseph  South Australia
#
#        country
# 967  Australia

# %% [markdown]
# Digunakan untuk menampilkan data pelanggan dengan usia paling tinggi pada DataFrame customers_df.

# %%
customers_df.age.replace(customers_df.age.max(), 70, inplace=True)
# Out:
# /tmp/ipython-input-4147959128.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   customers_df.age.replace(customers_df.age.max(), 70, inplace=True)

# %% [markdown]
# Digunakan untuk mengganti nilai usia tertinggi pada kolom age menjadi 70 dan langsung menyimpan perubahannya di DataFrame customers_df.

# %%
  customers_df[customers_df.age == customers_df.age.max()]
# Out:
#      customer_id customer_name             gender  age  \
# 215          216     fulan 216  Prefer not to say  500
#
#                home_address  zip_code       city               state  \
# 215  038 Haley MewsApt. 810      3991  Bayertown  Northern Territory
#
#        country
# 215  Australia

# %% [markdown]
# Digunakan untuk menampilkan data pelanggan dengan usia tertinggi setelah dilakukan perubahan nilai pada kolom age.

# %%
customers_df.age.replace(customers_df.age.max(), 50, inplace=True)
# Out:
# /tmp/ipython-input-606824494.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   customers_df.age.replace(customers_df.age.max(), 50, inplace=True)

# %% [markdown]
# Digunakan untuk mengganti nilai usia tertinggi pada kolom age menjadi 50 dan langsung menyimpan perubahannya di DataFrame customers_df.

# %%
customers_df[customers_df.age == customers_df.age.max()]
# Out:
#      customer_id customer_name             gender  age  \
# 6              7       fulan 7  Prefer not to say   76
# 85            86      fulan 86  Prefer not to say   76
# 190          191     fulan 191  Prefer not to say   76
# 335          335     fulan 335               Male   76
# 348          348     fulan 348  Prefer not to say   76
# 379          379     fulan 379  Prefer not to say   76
# 520          520     fulan 520  Prefer not to say   76
# 542          542     fulan 542  Prefer not to say   76
# 585          584     fulan 584  Prefer not to say   76
# 680          679     fulan 679  Prefer not to say   76
# 787          784     fulan 784               Male   76
# 812          809     fulan 809  Prefer not to say   76
# 901          897     fulan 897               Male   76
#
#                        home_address  zip_code           city  \
# 6       92 Hills Station StApt. 683       793      Masonfurt
# 85      040 Savannah GroveSuite 967      9337    Gleasonport
# ...

# %% [markdown]
# Digunakan untuk menampilkan data pelanggan dengan usia paling tinggi setelah pembaruan terakhir pada kolom age.

# %%
customers_df.describe()
# Out:
#        customer_id          age     zip_code
# count  1001.000000  1001.000000  1001.000000
# mean    500.942058    48.071928  5000.693307
# std     289.013599    15.997088  2886.084454
# min       1.000000    20.000000     2.000000
# 25%     251.000000    34.000000  2398.000000
# 50%     501.000000    50.000000  5079.000000
# 75%     751.000000    61.000000  7454.000000
# max    1000.000000    76.000000  9998.000000

# %% [markdown]
# Digunakan untuk menampilkan ringkasan statistik data numerik pada DataFrame customers_df.

# %%
datetime_columns = ["order_date", "delivery_date"]

for column in datetime_columns:
  orders_df[column] = pd.to_datetime(orders_df[column])

# %% [markdown]
# - Digunakan untuk menentukan kolom yang berisi data tanggal.
# - Digunakan untuk mengubah tipe data kolom tanggal menjadi format datetime agar bisa diolah dengan benar.

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       1000 non-null   int64
#  1   customer_id    1000 non-null   int64
#  2   payment        1000 non-null   int64
#  3   order_date     1000 non-null   datetime64[ns]
#  4   delivery_date  1000 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), int64(3)
# memory usage: 39.2 KB

# %% [markdown]
# Digunakan untuk menampilkan struktur dan tipe data pada DataFrame orders_df, termasuk memastikan kolom tanggal sudah bertipe datetime.

# %%
products_df.drop_duplicates(inplace=True)

# %% [markdown]
# Digunakan untuk menghapus data duplikat pada DataFrame products_df dan menyimpan perubahannya langsung tanpa membuat DataFrame baru.

# %%
print("Jumlah duplikasi: ", products_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# Digunakan untuk menampilkan jumlah data duplikat yang tersisa pada DataFrame products_df.

# %%
sales_df[sales_df.total_price.isna()]
# Out:
#       sales_id  order_id  product_id  price_per_unit  quantity  total_price
# 9            9         2        1196             105         1          NaN
# 121        121        27        1027              90         3          NaN
# 278        278        63         360              94         2          NaN
# 421        421        95        1091             115         1          NaN
# 489        489       108        1193             105         3          NaN
# 539        539       117         405             119         2          NaN
# 636        636       134         653              93         3          NaN
# 687        687       145        1138             102         1          NaN
# 854        854       177          64             104         1          NaN
# 1079      1079       222         908              94         3          NaN
# 1193      1193       248        1121             102         2          NaN
# ...

# %% [markdown]
# Digunakan untuk menampilkan baris data pada sales_df yang nilai total_price-nya kosong (NaN).

# %%
sales_df["total_price"] = sales_df["price_per_unit"] * sales_df["quantity"]

# %% [markdown]
# Digunakan untuk menghitung total harga dengan mengalikan price_per_unit dan quantity, lalu menyimpannya ke kolom total_price.

# %%
sales_df.isna().sum()
# Out:
# sales_id          0
# order_id          0
# product_id        0
# price_per_unit    0
# quantity          0
# total_price       0
# dtype: int64

# %% [markdown]
# Digunakan untuk menampilkan jumlah data kosong (NaN) pada setiap kolom di DataFrame sales_df.

# %%
customers_df.describe(include="all")
# Out:
#         customer_id customer_name             gender          age  \
# count   1001.000000          1001                983  1001.000000
# unique          NaN          1000                  3          NaN
# top             NaN     fulan 943  Prefer not to say          NaN
# freq            NaN             2                725          NaN
# mean     500.942058           NaN                NaN    48.071928
# std      289.013599           NaN                NaN    15.997088
# min        1.000000           NaN                NaN    20.000000
# 25%      251.000000           NaN                NaN    34.000000
# 50%      501.000000           NaN                NaN    50.000000
# 75%      751.000000           NaN                NaN    61.000000
# max     1000.000000           NaN                NaN    76.000000
#
#                       home_address     zip_code        city            state  \
# count                         1001  1001.000000        1001             1001
# ...

# %% [markdown]
# Digunakan untuk menampilkan ringkasan statistik semua kolom (numerik dan non-numerik) pada DataFrame customers_df.

# %%
customers_df.groupby(by="gender").agg({
    "customer_id": "nunique",
    "age": ["max", "min", "mean", "std"]
})
# Out:
#                   customer_id age
#                       nunique max min       mean        std
# gender
# Female                    115  75  20  47.678261  15.186298
# Male                      143  76  20  48.804196  16.438215
# Prefer not to say         725  76  20  48.013793  16.068906

# %% [markdown]
# Digunakan untuk mengelompokkan data berdasarkan gender, lalu:
# - menghitung jumlah pelanggan unik
# - menghitung usia maksimum, minimum, rata-rata, dan standar deviasi pada tiap gender.

# %%
customers_df.groupby(by="city").customer_id.nunique().sort_values(ascending=False)
# Out:
# city
# East Sophia     3
# New Ava         3
# East Aidan      3
# Lake Sienna     2
# Jademouth       2
#                ..
# Justinport      1
# Kaiberg         1
# Kaifort         1
# Kaihaven        1
# Johnsonhaven    1
# Name: customer_id, Length: 961, dtype: int64

# %% [markdown]
# Digunakan untuk menghitung jumlah pelanggan unik di setiap kota, lalu mengurutkannya dari yang terbanyak ke paling sedikit.

# %%
customers_df.groupby(by="state").customer_id.nunique().sort_values(ascending=False)
# Out:
# state
# South Australia                 139
# Queensland                      134
# New South Wales                 132
# Northern Territory              125
# Western Australia               124
# Australian Capital Territory    121
# Victoria                        121
# Tasmania                        104
# Name: customer_id, dtype: int64

# %% [markdown]
# Digunakan untuk menghitung jumlah pelanggan unik di setiap provinsi/state, lalu mengurutkannya dari yang terbanyak ke paling sedikit.

# %%
delivery_time = orders_df["delivery_date"] - orders_df["order_date"]
delivery_time = delivery_time.apply(lambda x: x.total_seconds())
orders_df["delivery_time"] = round(delivery_time/86400)

# %% [markdown]
# - Menghitung selisih waktu pengiriman antara tanggal pesan dan tanggal diterima.
# - Mengubah selisih waktu tersebut menjadi detik.
# - Mengonversi detik menjadi hari, lalu menyimpannya ke kolom delivery_time.

# %%
orders_df.describe(include="all")
# Out:
#           order_id  customer_id       payment                  order_date  \
# count  1000.000000  1000.000000   1000.000000                        1000
# mean    500.500000   506.640000  33972.936000  2021-05-27 18:38:52.800000
# min       1.000000     1.000000  10043.000000         2021-01-01 00:00:00
# 25%     250.750000   275.250000  21329.250000         2021-03-13 18:00:00
# 50%     500.500000   515.000000  33697.500000         2021-05-27 12:00:00
# 75%     750.250000   737.250000  46249.000000         2021-08-12 06:00:00
# max    1000.000000  1000.000000  59910.000000         2021-10-24 00:00:00
# std     288.819436   277.115502  14451.609047                         NaN
#
#              delivery_date  delivery_time
# count                 1000    1000.000000
# mean   2021-06-10 20:31:12      14.078000
# min    2021-01-03 00:00:00       1.000000
# 25%    2021-03-28 00:00:00       8.000000
# 50%    2021-06-11 12:00:00      14.000000
# 75%    2021-08-24 06:00:00      21.000000
# ...

# %% [markdown]
# Digunakan untuk menampilkan ringkasan statistik semua kolom (numerik dan non-numerik) pada DataFrame orders_df.

# %%
customer_id_in_orders_df =  orders_df.customer_id.tolist()
customers_df["status"] = customers_df["customer_id"].apply(lambda x: "Active" if x in customer_id_in_orders_df else "Non Active")
customers_df.sample(5)
# Out:
#      customer_id customer_name             gender  age  \
# 763          761     fulan 761  Prefer not to say   52
# 450          450     fulan 450  Prefer not to say   59
# 956          950     fulan 950               Male   43
# 595          594     fulan 594               Male   44
# 923          918     fulan 918  Prefer not to say   69
#
#                      home_address  zip_code           city  \
# 763       080 Tahlia LaneApt. 450      3739  West Aidanton
# 450        655 Max TrailSuite 049      5146      West Lucy
# 956         3414 Mia MallApt. 446      3051      Bergefort
# 595  275 Little Estate DrApt. 926      1335         Avaton
# 923       056 Khan RidgeSuite 131      1328     Violetstad
#
#                             state    country      status
# 763                      Victoria  Australia      Active
# 450               New South Wales  Australia      Active
# 956                      Victoria  Australia      Active
# ...

# %% [markdown]
# - Mengambil seluruh customer_id dari orders_df dan menyimpannya dalam bentuk list.
# - Menambahkan kolom status: Active untuk pelanggan pernah melakukan pesanan
# dan Non Active untuk pelanggan belum pernah melakukan pesanan.
# - Menampilkan 5 data pelanggan secara acak untuk melihat hasil perubahan.

# %%
customers_df.groupby(by="status").customer_id.count()
# Out:
# status
# Active        617
# Non Active    384
# Name: customer_id, dtype: int64

# %% [markdown]
# Digunakan untuk menghitung jumlah pelanggan pada setiap status (Active dan Non Active).

# %%
orders_customers_df = pd.merge(
    left=orders_df,
    right=customers_df,
    how="left",
    left_on="customer_id",
    right_on="customer_id"
)
orders_customers_df.head()
# Out:
#    order_id  customer_id  payment order_date delivery_date  delivery_time  \
# 0         1           64    30811 2021-08-30    2021-09-24           25.0
# 1         2          473    50490 2021-02-03    2021-02-13           10.0
# 2         3          774    46763 2021-10-08    2021-11-03           26.0
# 3         4          433    39782 2021-05-06    2021-05-19           13.0
# 4         5          441    14719 2021-03-23    2021-03-24            1.0
#
#   customer_name             gender  age                   home_address  \
# 0      fulan 64  Prefer not to say   75      4927 Alice MeadowApt. 960
# 1     fulan 473               Male   61  531 Schmitt BoulevardApt. 010
# 2     fulan 774  Prefer not to say   34       2096 Wilson MewsApt. 714
# 3     fulan 433  Prefer not to say   46        5777 Mayer PassApt. 881
# 4     fulan 441  Prefer not to say   53   33 Richards JunctionApt. 478
#
#    zip_code                city              state    country  status
# ...

# %% [markdown]
# - Digunakan untuk menggabungkan data orders_df dan customers_df berdasarkan kolom customer_id menggunakan left join.
# Semua data dari orders_df tetap ada
# Data pelanggan dari customers_df ditambahkan sesuai customer_id
# - Menampilkan 5 baris pertama dari DataFrame hasil penggabungan.

# %%
orders_customers_df.groupby(by="city").order_id.nunique().sort_values(ascending=False).reset_index().head(10)
# Out:
#                city  order_id
# 0        Jordanside         6
# 1           New Ava         6
# 2  Port Hannahburgh         5
# 3         Lake Rose         5
# 4        O'keefeton         5
# 5          East Max         5
# 6          Rubyfort         5
# 7          West Kai         5
# 8         Sarahstad         4
# 9        Russelstad         4

# %% [markdown]
# Digunakan untuk:
# - Mengelompokkan data berdasarkan kota (city)
# - Menghitung jumlah pesanan unik (order_id) di setiap kota
# - Mengurutkan dari yang terbanyak ke paling sedikit
# - Mereset index agar rapi
# - Menampilkan 10 kota dengan jumlah pesanan terbanyak.

# %%
orders_customers_df.groupby(by="state").order_id.nunique().sort_values(ascending=False)
# Out:
# state
# South Australia                 148
# Queensland                      139
# Western Australia               130
# New South Wales                 129
# Victoria                        118
# Australian Capital Territory    118
# Tasmania                        112
# Northern Territory              106
# Name: order_id, dtype: int64

# %% [markdown]
# Digunakan untuk:
# - Mengelompokkan data berdasarkan provinsi/state (state)
# - Menghitung jumlah pesanan unik (order_id) di setiap provinsi
# - Mengurutkan dari yang terbanyak ke paling sedikit.

# %%
orders_customers_df.groupby(by="gender").order_id.nunique().sort_values(ascending=False)
# Out:
# gender
# Prefer not to say    716
# Female               139
# Male                 136
# Name: order_id, dtype: int64

# %% [markdown]
# Digunakan untuk:
# - Mengelompokkan data berdasarkan jenis kelamin (gender)
# - Menghitung jumlah pesanan unik (order_id) untuk tiap gender
# - Mengurutkan dari yang terbanyak ke paling sedikit.

# %%
orders_customers_df["age_group"] = orders_customers_df.age.apply(lambda x: "Youth" if x <= 24 else ("Seniors" if x > 64 else "Adults"))

# %% [markdown]
# Digunakan untuk menambahkan kolom age_group berdasarkan usia pelanggan:
# Youth untuk usia ≤ 24
# Adults untuk usia 25–64
# Seniors untuk usia > 64

# %%
orders_customers_df.groupby(by="age_group").order_id.nunique().sort_values(ascending=False)
# Out:
# age_group
# Adults     732
# Seniors    175
# Youth       93
# Name: order_id, dtype: int64

# %% [markdown]
# Digunakan untuk:
# - Mengelompokkan data berdasarkan kelompok usia (age_group)
# - Menghitung jumlah pesanan unik (order_id) di setiap kelompok usia
# - Mengurutkan dari yang terbanyak ke paling sedikit.

# %%
products_df.describe(include="all")
# Out:
#          product_id product_type product_name  size colour        price  \
# count   1260.000000         1260         1260  1260   1260  1260.000000
# unique          NaN            3           35     8      7          NaN
# top             NaN        Shirt        Denim    XS    red          NaN
# freq            NaN          420           70   252    180          NaN
# mean     629.500000          NaN          NaN   NaN    NaN   105.805556
# std      363.874979          NaN          NaN   NaN    NaN     9.704423
# min        0.000000          NaN          NaN   NaN    NaN    90.000000
# 25%      314.750000          NaN          NaN   NaN    NaN    95.750000
# 50%      629.500000          NaN          NaN   NaN    NaN   108.500000
# 75%      944.250000          NaN          NaN   NaN    NaN   114.000000
# max     1259.000000          NaN          NaN   NaN    NaN   119.000000
#
#            quantity                                        description
# ...

# %% [markdown]
# Digunakan untuk menampilkan ringkasan statistik semua kolom (numerik dan non-numerik) pada DataFrame products_df.

# %%
sales_df.describe(include="all")
# Out:
#           sales_id     order_id   product_id  price_per_unit    quantity  \
# count  5000.000000  5000.000000  5000.000000     5000.000000  5000.00000
# mean   2499.500000   503.038200   634.053200      103.501600     1.99240
# std    1443.520003   285.964418   363.255794        9.195004     0.80751
# min       0.000000     1.000000     1.000000       90.000000     1.00000
# 25%    1249.750000   258.000000   323.000000       95.000000     1.00000
# 50%    2499.500000   504.500000   635.000000      102.000000     2.00000
# 75%    3749.250000   749.000000   951.000000      112.000000     3.00000
# max    4999.000000   999.000000  1259.000000      119.000000     3.00000
#
#        total_price
# count  5000.000000
# mean    206.360000
# std      86.357457
# min      90.000000
# 25%     112.000000
# 50%     204.000000
# 75%     285.000000
# max     357.000000

# %% [markdown]
# Digunakan untuk menampilkan ringkasan statistik semua kolom (numerik dan non-numerik) pada DataFrame sales_df.

# %%
products_df.sort_values(by="price", ascending=False)
# Out:
#       product_id product_type product_name size  colour  price  quantity  \
# 671          665       Jacket        Parka   XS     red    119        65
# 672          666       Jacket        Parka    S     red    119        66
# 673          667       Jacket        Parka    M     red    119        56
# 674          668       Jacket        Parka    L     red    119        73
# 675          669       Jacket        Parka   XL     red    119        64
# ...          ...          ...          ...  ...     ...    ...       ...
# 1222        1216     Trousers      Pleated    S  indigo     90        41
# 1229        1223     Trousers      Pleated    L  violet     90        48
# 1228        1222     Trousers      Pleated    M  violet     90        45
# 1227        1221     Trousers      Pleated    S  violet     90        50
# 1226        1220     Trousers      Pleated   XS  violet     90        58
#
#                                         description
# ...

# %% [markdown]
# Digunakan untuk mengurutkan data produk berdasarkan harga (price) dari yang tertinggi ke terendah.

# %%
products_df.groupby(by="product_type").agg({
    "product_id": "nunique",
    "quantity": "sum",
    "price":  ["min", "max"]
})
# Out:
#              product_id quantity price
#                 nunique      sum   min  max
# product_type
# Jacket              420    25387    90  119
# Shirt               420    25263    92  119
# Trousers            420    25139    90  119

# %% [markdown]
# Digunakan untuk:
# - Mengelompokkan data berdasarkan tipe produk (product_type)
# - Menghitung:
# Jumlah produk unik (product_id)
# Total kuantitas (quantity)
# Harga minimum dan maksimum (price) per tipe produk.

# %%
products_df.groupby(by="product_name").agg({
    "product_id": "nunique",
    "quantity": "sum",
    "price": ["min", "max"]
})
# Out:
#                   product_id quantity price
#                      nunique      sum   min  max
# product_name
# Bomber                    35     2083    90   90
# Camp Collared             35     2071   112  112
# Cardigan                  35     2032   118  118
# Cargo Pants               35     2146   106  106
# Casual Slim Fit           35     2086   113  113
# Chambray                  35     2020   105  105
# Chinos                    35     2101   100  100
# Coach                     35     2158   115  115
# Cords                     35     2260   113  113
# Cropped                   35     2085    99   99
# Cuban Collar              35     2017    93   93
# Denim                     70     4204    92  115
# Drawstring                35     2042   104  104
# Dress                     35     2125   119  119
# Flannel                   35     2135    96   96
# Henley                    35     2051    92   92
# High-Waisted              35     2198    98   98
# ...

# %% [markdown]
# Digunakan untuk:
# - Mengelompokkan data berdasarkan nama produk (product_name)
# - Menghitung:
# Jumlah produk unik (product_id)
# Total kuantitas (quantity)
# Harga minimum dan maksimum (price) per nama produk.

# %%
sales_products_df = pd.merge(
    left=sales_df,
    right=products_df,
    how="left",
    left_on="product_id",
    right_on="product_id"
)
sales_products_df.head()
# Out:
#    sales_id  order_id  product_id  price_per_unit  quantity_x  total_price  \
# 0         0         1         218             106           2          212
# 1         1         1         481             118           1          118
# 2         2         1           2              96           3          288
# 3         3         1        1002             106           2          212
# 4         4         1         691             113           3          339
#
#   product_type  product_name size  colour  price  quantity_y  \
# 0        Shirt      Chambray    L  orange    105          44
# 1       Jacket        Puffer    S  indigo    110          62
# 2        Shirt  Oxford Cloth    M     red    114          54
# 3     Trousers          Wool    M    blue    111          52
# 4       Jacket         Parka    S  indigo    119          53
#
#                                    description
# 0   A orange coloured, L sized, Chambray Shirt
# 1    A indigo coloured, S sized, Puffer Jacket
# ...

# %% [markdown]
# - Digunakan untuk menggabungkan data sales_df dan products_df berdasarkan kolom product_id menggunakan left join. Semua data dari sales_df tetap ada. Data produk dari products_df ditambahkan sesuai product_id
# - Menampilkan 5 baris pertama dari DataFrame hasil penggabungan.

# %%
sales_products_df.groupby(by="product_type").agg({
    "sales_id": "nunique",
    "quantity_x": "sum",
    "total_price": "sum"
})
# Out:
#               sales_id  quantity_x  total_price
# product_type
# Jacket            1676        3343       357026
# Shirt             1641        3259       333600
# Trousers          1683        3360       341174

# %% [markdown]
# Digunakan untuk:
# - Mengelompokkan data berdasarkan tipe produk (product_type)
# - Menghitung:
# Jumlah penjualan unik (sales_id)
# Total kuantitas terjual (quantity_x)
# Total pendapatan (total_price) per tipe produk.

# %%
sales_products_df.groupby(by="product_name").agg({
    "sales_id": "nunique",
    "quantity_x": "sum",
    "total_price": "sum"
}).sort_values(by="total_price", ascending=False)
# Out:
#                    sales_id  quantity_x  total_price
# product_name
# Denim                   273         527        52399
# Casual Slim Fit         154         306        36414
# Trench Coat             146         299        35581
# Shearling               150         302        35334
# Puffer                  140         298        35164
# Flannel                 141         281        33158
# Cropped                 135         284        32660
# Pleated                 147         308        32340
# Joggers                 164         334        31062
# Chambray                141         290        30740
# Parka                   134         269        30397
# Bomber                  150         297        29700
# Chinos                  135         260        29380
# Windbreaker             143         287        29274
# Cardigan                134         260        29120
# Peacoat                 132         266        28994
# ...

# %% [markdown]
# Digunakan untuk:
# - Mengelompokkan data berdasarkan nama produk (product_name)
# - Menghitung:
# Jumlah penjualan unik (sales_id)
# Total kuantitas terjual (quantity_x)
# Total pendapatan (total_price) per produk
# - Mengurutkan produk berdasarkan total pendapatan dari tertinggi ke terendah.

# %%
all_df = pd.merge(
    left=sales_products_df,
    right=orders_customers_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
all_df.head()
# Out:
#    sales_id  order_id  product_id  price_per_unit  quantity_x  total_price  \
# 0         0         1         218             106           2          212
# 1         1         1         481             118           1          118
# 2         2         1           2              96           3          288
# 3         3         1        1002             106           2          212
# 4         4         1         691             113           3          339
#
#   product_type  product_name size  colour  ...  customer_name  \
# 0        Shirt      Chambray    L  orange  ...       fulan 64
# 1       Jacket        Puffer    S  indigo  ...       fulan 64
# 2        Shirt  Oxford Cloth    M     red  ...       fulan 64
# 3     Trousers          Wool    M    blue  ...       fulan 64
# 4       Jacket         Parka    S  indigo  ...       fulan 64
#
#               gender age               home_address  zip_code            city  \
# ...

# %% [markdown]
# - Digunakan untuk menggabungkan data penjualan-produk (sales_products_df) dengan data pesanan-pelanggan (orders_customers_df) berdasarkan kolom order_id menggunakan left join.
# Semua data dari sales_products_df tetap ada
# Data pesanan dan pelanggan dari orders_customers_df ditambahkan sesuai order_id
# - Menampilkan 5 baris pertama dari DataFrame hasil penggabungan.

# %%
all_df.groupby(by=["state", "product_type"]).agg({
    "quantity_x": "sum",
    "total_price": "sum"
})
# Out:
#                                            quantity_x  total_price
# state                        product_type
# Australian Capital Territory Jacket               406        43204
#                              Shirt                396        40448
#                              Trousers             454        46790
# New South Wales              Jacket               451        47998
#                              Shirt                431        43980
#                              Trousers             392        39766
# Northern Territory           Jacket               365        38991
#                              Shirt                336        33865
#                              Trousers             384        38998
# Queensland                   Jacket               499        53511
#                              Shirt                417        42506
#                              Trousers             453        46045
# ...

# %% [markdown]
# Digunakan untuk:
# - Mengelompokkan data berdasarkan provinsi (state) dan tipe produk (product_type)
# - Menghitung:
# Total kuantitas terjual (quantity_x)
# Total pendapatan (total_price)
# untuk tiap kombinasi provinsi dan tipe produk.

# %%
all_df.groupby(by=["gender", "product_type"]).agg({
    "quantity_x": "sum",
    "total_price": "sum"
})
# Out:
#                                 quantity_x  total_price
# gender            product_type
# Female            Jacket               481        50963
#                   Shirt                445        45146
#                   Trousers             481        49295
# Male              Jacket               480        50978
#                   Shirt                410        41939
#                   Trousers             453        46071
# Prefer not to say Jacket              2349       251486
#                   Shirt               2386       244765
#                   Trousers            2400       243092

# %% [markdown]
# Digunakan untuk:
# - Mengelompokkan data berdasarkan jenis kelamin (gender) dan tipe produk (product_type)
# - Menghitung:
# Total kuantitas terjual (quantity_x)
# Total pendapatan (total_price)
# untuk tiap kombinasi gender dan tipe produk.

# %%
  all_df.groupby(by=["age_group", "product_type"]).agg({
      "quantity_x": "sum",
      "total_price": "sum"
  })
# Out:
#                         quantity_x  total_price
# age_group product_type
# Adults    Jacket              2484       265685
#           Shirt               2358       241517
#           Trousers            2442       248648
# Seniors   Jacket               585        62329
#           Shirt                600        61241
#           Trousers             596        60094
# Youth     Jacket               274        29012
#           Shirt                301        30842
#           Trousers             322        32432

# %% [markdown]
# Digunakan untuk:
# - Mengelompokkan data berdasarkan kelompok usia (age_group) dan tipe produk (product_type)
# - Menghitung:
# Total kuantitas terjual (quantity_x)
# Total pendapatan (total_price)
# untuk tiap kombinasi kelompok usia dan tipe produk.
