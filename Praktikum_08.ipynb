# %% [markdown]
# <a href="https://colab.research.google.com/github/meilani-4232401011/Pemograman-Dasar-/blob/main/Praktikum_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Membuat data dummy mahasiswa
data = {
    'Nama': ['Aldi', 'Budi', 'Citra', 'Dewi', 'Eka', 'Fajar'],
    'Umur': [20, 21, 22, None, 23, 21],
    'Nilai_Tugas': [85, 90, None, 78, 88, 90],
    'Nilai_UAS': [80, 92, 85, 70, None, 95],
    'Jurusan': ['Energi', 'Energi', 'Teknik', 'Teknik', 'Energi', None]
}

df = pd.DataFrame(data)
df
df.info()
df.isnull().sum()
df.duplicated().sum()

# Mengisi nilai kosong di kolom numerik dengan nilai rata-rata
df['Umur'] = df['Umur'].fillna(df['Umur'].mean())
df['Nilai_Tugas'] = df['Nilai_Tugas'].fillna(df['Nilai_Tugas'].mean())
df['Nilai_UAS'] = df['Nilai_UAS'].fillna(df['Nilai_UAS'].mean())

# Mengisi nilai kosong di kolom kategorik dengan 'Tidak Diketahui'
df['Jurusan'] = df['Jurusan'].fillna('Tidak Diketahui')

df

# Tambahkan satu data duplikat untuk simulasi
df.loc[len(df)] = ['Aldi', 20, 85, 80, 'Energi']

# Cek jumlah duplikat
print("Jumlah duplikat sebelum dihapus:", df.duplicated().sum())

# Hapus duplikat
df = df.drop_duplicates()

print("Jumlah duplikat setelah dihapus:", df.duplicated().sum())

# Ubah semua nama jurusan menjadi huruf kapital
df['Jurusan'] = df['Jurusan'].str.upper()

df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Nama         6 non-null      object
#  1   Umur         5 non-null      float64
#  2   Nilai_Tugas  5 non-null      float64
#  3   Nilai_UAS    5 non-null      float64
#  4   Jurusan      5 non-null      object
# dtypes: float64(3), object(2)
# memory usage: 372.0+ bytes
# Jumlah duplikat sebelum dihapus: 1
# Jumlah duplikat setelah dihapus: 0
#     Nama  Umur  Nilai_Tugas  Nilai_UAS          Jurusan
# 0   Aldi  20.0         85.0       80.0           ENERGI
# 1   Budi  21.0         90.0       92.0           ENERGI
# 2  Citra  22.0         86.2       85.0           TEKNIK
# 3   Dewi  21.4         78.0       70.0           TEKNIK
# 4    Eka  23.0         88.0       84.4           ENERGI
# 5  Fajar  21.0         90.0       95.0  TIDAK DIKETAHUI

# %%
import pandas as pd

# Membuat data dummy mahasiswa
data = {
    'Nama': ['Aldi', 'Budi', 'Citra', 'Dewi', 'Eka', 'Fajar'],
    'Umur': [20, 21, 22, None, 23, 21],
    'Nilai_Tugas': [85, 90, None, 78, 88, 90],
    'Nilai_UAS': [80, 92, 85, 70, None, 95],
    'Jurusan': ['Energi', 'Energi', 'Teknik', 'Teknik', 'Energi', None]
}

df = pd.DataFrame(data)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Nama         6 non-null      object
#  1   Umur         5 non-null      float64
#  2   Nilai_Tugas  5 non-null      float64
#  3   Nilai_UAS    5 non-null      float64
#  4   Jurusan      5 non-null      object
# dtypes: float64(3), object(2)
# memory usage: 372.0+ bytes

# %% [markdown]
# Penjelasan 3 a
# df.info() menunjukkan bahwa:
# DataFrame punya 6 baris dan 5 kolom.
# Ada 4 kolom yang memiliki 1 data kosong (Umur, Nilai_Tugas, Nilai_UAS, Jurusan).
# Tipe data: object untuk teks, float64 untuk angka.

# %%
import pandas as pd

# Membuat data dummy mahasiswa
data = {
    'Nama': ['Aldi', 'Budi', 'Citra', 'Dewi', 'Eka', 'Fajar'],
    'Umur': [20, 21, 22, None, 23, 21],
    'Nilai_Tugas': [85, 90, None, 78, 88, 90],
    'Nilai_UAS': [80, 92, 85, 70, None, 95],
    'Jurusan': ['Energi', 'Energi', 'Teknik', 'Teknik', 'Energi', None]
}

df = pd.DataFrame(data)
df.describe()
# Out:
#             Umur  Nilai_Tugas  Nilai_UAS
# count   5.000000      5.00000   5.000000
# mean   21.400000     86.20000  84.400000
# std     1.140175      5.01996   9.964939
# min    20.000000     78.00000  70.000000
# 25%    21.000000     85.00000  80.000000
# 50%    21.000000     88.00000  85.000000
# 75%    22.000000     90.00000  92.000000
# max    23.000000     90.00000  95.000000

# %% [markdown]
# penjelasan 3 b
# df.describe() memberi ringkasan statistik untuk kolom numerik.
#
# count adalah jumlah data yang tidak kosong.
# mean adalah nilai rata-rata.
# std adalah seberapa besar variasi data.
# min adalah nilai terkecil.
# 25%, 50%, 75% berarti kuartil (pembagian data saat diurutkan).
# max adalah nilai terbesar.

# %%
import pandas as pd

# Membuat data dummy mahasiswa
data = {
    'Nama': ['Aldi', 'Budi', 'Citra', 'Dewi', 'Eka', 'Fajar'],
    'Umur': [20, 21, 22, None, 23, 21],
    'Nilai_Tugas': [85, 90, None, 78, 88, 90],
    'Nilai_UAS': [80, 92, 85, 70, None, 95],
    'Jurusan': ['Energi', 'Energi', 'Teknik', 'Teknik', 'Energi', None]
}

df = pd.DataFrame(data)
df.isnull().sum()
# Out:
# Nama           0
# Umur           1
# Nilai_Tugas    1
# Nilai_UAS      1
# Jurusan        1
# dtype: int64

# %% [markdown]
# Penjelasan 3 b
# df.isnull().sum() menghitung berapa banyak data yang kosong (NaN) di setiap kolom.
#
# Hasilnya:
# Nama → 0 (tidak ada data kosong)
# Umur → 1 data kosong
# Nilai_Tugas → 1 data kosong
# Nilai_UAS → 1 data kosong
# Jurusan → 1 data kosong
# Jadi ada 4 kolom yang masing-masing memiliki 1 nilai yang hilang.

# %%
import pandas as pd

# Membuat data dummy mahasiswa
data = {
    'Nama': ['Aldi', 'Budi', 'Citra', 'Dewi', 'Eka', 'Fajar'],
    'Umur': [20, 21, 22, None, 23, 21],
    'Nilai_Tugas': [85, 90, None, 78, 88, 90],
    'Nilai_UAS': [80, 92, 85, 70, None, 95],
    'Jurusan': ['Energi', 'Energi', 'Teknik', 'Teknik', 'Energi', None]
}

df = pd.DataFrame(data)
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Penjelasan 3 d
# df.duplicated().sum() digunakan untuk menghitung berapa banyak baris yang duplikat di DataFrame.

# %%
# Mengisi nilai kosong di kolom numerik dengan nilai rata-rata
df['Umur'] = df['Umur'].fillna(df['Umur'].mean())
df['Nilai_Tugas'] = df['Nilai_Tugas'].fillna(df['Nilai_Tugas'].mean())
df['Nilai_UAS'] = df['Nilai_UAS'].fillna(df['Nilai_UAS'].mean())

# Mengisi nilai kosong di kolom kategorik dengan 'Tidak Diketahui'
df['Jurusan'] = df['Jurusan'].fillna('Tidak Diketahui')

df

# Tambahkan satu data duplikat untuk simulasi
df.loc[len(df)] = ['Aldi', 20, 85, 80, 'Energi']

# Cek jumlah duplikat
print("Jumlah duplikat sebelum dihapus:", df.duplicated().sum())

# Hapus duplikat
df = df.drop_duplicates()

print("Jumlah duplikat setelah dihapus:", df.duplicated().sum())

# Ubah semua nama jurusan menjadi huruf kapital
df['Jurusan'] = df['Jurusan'].str.upper()

df
# Out:
# Jumlah duplikat sebelum dihapus: 1
# Jumlah duplikat setelah dihapus: 0
#     Nama  Umur  Nilai_Tugas  Nilai_UAS          Jurusan
# 0   Aldi  20.0         85.0       80.0           ENERGI
# 1   Budi  21.0         90.0       92.0           ENERGI
# 2  Citra  22.0         86.2       85.0           TEKNIK
# 3   Dewi  21.4         78.0       70.0           TEKNIK
# 4    Eka  23.0         88.0       84.4           ENERGI
# 5  Fajar  21.0         90.0       95.0  TIDAK DIKETAHUI

# %% [markdown]
# Penjelasan no 4:
# Nilai kosong pada kolom numerik diisi dengan rata-rata, dan kolom Jurusan diisi dengan "Tidak Diketahui".
# Satu baris duplikat ditambahkan, lalu dihitung jumlah duplikatnya.
# Duplikat kemudian dihapus dengan drop_duplicates().
# Kolom Jurusan diubah menjadi huruf kapital seluruhnya.
# Itu inti dari seluruh proses kodenya.
